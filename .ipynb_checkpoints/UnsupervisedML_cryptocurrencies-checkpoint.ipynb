# %%
# RECOMMENDATION: The output from t-sne and K-means clustering displayed that crypto currencies cannot be clustered together in any number of clusters.That being said, distinct groups of currencies were not identified and, therefore, no trends coudl be drawn.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
# Read `crypto_data.csv` into Pandas.

# %%
cryptocurrency_df = pd.read_csv("Data/crypto_data.csv")

# %%
cryptocurrency_df
# Out:
#      Unnamed: 0        CoinName Algorithm  IsTrading ProofType  \
# 0            42         42 Coin    Scrypt       True   PoW/PoS
# 1           365         365Coin       X11       True   PoW/PoS
# 2           404         404Coin    Scrypt       True   PoW/PoS
# 3           611       SixEleven   SHA-256       True       PoW
# 4           808             808   SHA-256       True   PoW/PoS
# ...         ...             ...       ...        ...       ...
# 1247        XBC     BitcoinPlus    Scrypt       True       PoS
# 1248       DVTC      DivotyCoin    Scrypt      False   PoW/PoS
# 1249       GIOT     Giotto Coin    Scrypt      False   PoW/PoS
# 1250       OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS
# 1251       PUNK       SteamPunk       PoS      False       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# ...

# %%
# Discard all cryptocurrencies that are not being traded.

# %%
cryptocurrency_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1252 entries, 0 to 1251
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1252 non-null   object
#  1   CoinName         1252 non-null   object
#  2   Algorithm        1252 non-null   object
#  3   IsTrading        1252 non-null   bool
#  4   ProofType        1252 non-null   object
#  5   TotalCoinsMined  744 non-null    float64
#  6   TotalCoinSupply  1252 non-null   object
# dtypes: bool(1), float64(1), object(5)
# memory usage: 60.0+ KB

# %%
cryptocurrency_df2 = pd.DataFrame(cryptocurrency_df)

# %%
cryptocurrency_df2.query('IsTrading == True & TotalCoinsMined > 0', inplace=True)
cryptocurrency_df2
# Out:
#      Unnamed: 0     CoinName    Algorithm  IsTrading ProofType  \
# 0            42      42 Coin       Scrypt       True   PoW/PoS
# 2           404      404Coin       Scrypt       True   PoW/PoS
# 5          1337    EliteCoin          X13       True   PoW/PoS
# 7           BTC      Bitcoin      SHA-256       True       PoW
# 8           ETH     Ethereum       Ethash       True       PoW
# ...         ...          ...          ...        ...       ...
# 1238       ZEPH       ZEPHYR      SHA-256       True      DPoS
# 1242        GAP      Gapcoin       Scrypt       True   PoW/PoS
# 1245        BDX       Beldex  CryptoNight       True       PoW
# 1246        ZEN      Horizen     Equihash       True       PoW
# 1247        XBC  BitcoinPlus       Scrypt       True       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 2        1.055185e+09       532000000
# 5        2.927942e+10    314159265359
# 7        1.792718e+07        21000000
# ...

# %%
cryptocurrency_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 532 entries, 0 to 1247
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       532 non-null    object
#  1   CoinName         532 non-null    object
#  2   Algorithm        532 non-null    object
#  3   IsTrading        532 non-null    bool
#  4   ProofType        532 non-null    object
#  5   TotalCoinsMined  532 non-null    float64
#  6   TotalCoinSupply  532 non-null    object
# dtypes: bool(1), float64(1), object(5)
# memory usage: 29.6+ KB

# %%
tradedcrypto_df = cryptocurrency_df2.drop(['Unnamed: 0', 'IsTrading', 'CoinName'], axis=1)

tradedcrypto_df
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0          Scrypt   PoW/PoS     4.199995e+01              42
# 2          Scrypt   PoW/PoS     1.055185e+09       532000000
# 5             X13   PoW/PoS     2.927942e+10    314159265359
# 7         SHA-256       PoW     1.792718e+07        21000000
# 8          Ethash       PoW     1.076842e+08               0
# ...           ...       ...              ...             ...
# 1238      SHA-256      DPoS     2.000000e+09      2000000000
# 1242       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245  CryptoNight       PoW     9.802226e+08      1400222610
# 1246     Equihash       PoW     7.296538e+06        21000000
# 1247       Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 4 columns]

# %%
#Converting "totalCoinsMined" and "TotalCoinSupply" to numeric

# %%
tradedcrypto_df['TotalCoinSupply'] = tradedcrypto_df['TotalCoinSupply'].astype(float)

tradedcrypto_df
# Out:
#         Algorithm ProofType  TotalCoinsMined  TotalCoinSupply
# 0          Scrypt   PoW/PoS     4.199995e+01     4.200000e+01
# 2          Scrypt   PoW/PoS     1.055185e+09     5.320000e+08
# 5             X13   PoW/PoS     2.927942e+10     3.141593e+11
# 7         SHA-256       PoW     1.792718e+07     2.100000e+07
# 8          Ethash       PoW     1.076842e+08     0.000000e+00
# ...           ...       ...              ...              ...
# 1238      SHA-256      DPoS     2.000000e+09     2.000000e+09
# 1242       Scrypt   PoW/PoS     1.493105e+07     2.500000e+08
# 1245  CryptoNight       PoW     9.802226e+08     1.400223e+09
# 1246     Equihash       PoW     7.296538e+06     2.100000e+07
# 1247       Scrypt       PoS     1.283270e+05     1.000000e+06
#
# [532 rows x 4 columns]

# %%
#Create dummy variables to convert string values to numeric

# %%
cryptofinal = pd.get_dummies(tradedcrypto_df)

cryptofinal
# Out:
#       TotalCoinsMined  TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 0        4.199995e+01     4.200000e+01                                 0
# 2        1.055185e+09     5.320000e+08                                 0
# 5        2.927942e+10     3.141593e+11                                 0
# 7        1.792718e+07     2.100000e+07                                 0
# 8        1.076842e+08     0.000000e+00                                 0
# ...               ...              ...                               ...
# 1238     2.000000e+09     2.000000e+09                                 0
# 1242     1.493105e+07     2.500000e+08                                 0
# 1245     9.802226e+08     1.400223e+09                                 0
# 1246     7.296538e+06     2.100000e+07                                 0
# 1247     1.283270e+05     1.000000e+06                                 0
#
#       Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# ...

# %%
#The "get dummies" convertion expanded the database into 98 columns.

# %%
#Standardize the dataset  by scaling the dataset.

# %%
scaler = StandardScaler()
scaled_df = scaler.fit_transform(cryptofinal)

# %%
scaled_crypto = pd.DataFrame(scaled_df, columns=cryptofinal.columns[0:])
scaled_crypto

scaled_crypto
# Out:
#      TotalCoinsMined  TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 0          -0.117108        -0.152870                         -0.043396
# 1          -0.093970        -0.145009                         -0.043396
# 2           0.524946         4.489424                         -0.043396
# 3          -0.116715        -0.152560                         -0.043396
# 4          -0.114747        -0.152870                         -0.043396
# ..               ...              ...                               ...
# 527        -0.073251        -0.123317                         -0.043396
# 528        -0.116781        -0.149176                         -0.043396
# 529        -0.095613        -0.132179                         -0.043396
# 530        -0.116948        -0.152560                         -0.043396
# 531        -0.117105        -0.152856                         -0.043396
#
#      Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# ...

# %%
#Use Principal Component Analysis for dimensionality reduction.

# %%
pca = PCA(n_components=0.90)

# %%
cryptoreduced = pca.fit_transform(scaled_crypto)

# %%
cryptoreduced_df = pd.DataFrame(data=cryptoreduced)
cryptoreduced_df.head()
# Out:
#          0         1         2         3             4             5   \
# 0 -0.335099  1.032189 -0.590713  0.001397  2.734816e-12 -5.326378e-15
# 1 -0.318434  1.032331 -0.591126  0.001386  2.712386e-12 -5.457883e-15
# 2  2.305468  1.656383 -0.683617  0.004731  9.322259e-12 -7.481406e-15
# 3 -0.145184 -1.320593  0.192813 -0.001229 -2.420624e-12  3.040430e-15
# 4 -0.151768 -2.036192  0.396182 -0.001705 -3.352037e-12  1.674182e-15
#
#              6         7         8         9   ...            64  \
# 0 -1.280445e-15 -0.007129 -1.319756 -0.051813  ... -4.948116e-16
# 1 -1.429030e-15 -0.007739 -1.322514 -0.056674  ... -4.936877e-16
# 2  6.356089e-15 -0.054781 -1.542879 -0.943951  ... -3.646047e-14
# 3 -1.007631e-15 -0.002071  0.281463  0.251862  ... -8.634350e-16
# 4 -1.227687e-15  0.027735  0.519099  0.188820  ...  1.284903e-13
#
#              65            66            67            68            69  \
# 0  3.888930e-15 -1.114145e-15 -1.150971e-15 -7.726513e-16 -3.626465e-16
# ...

# %%
# After using PCA and preserving 90% of the explained variance in dimensionality reduction, the number of features were reduced from 98 to 74.

# %%
pca.explained_variance_ratio_
# Out:
# array([0.0279317 , 0.02141802, 0.02051615, 0.02044661, 0.0204466 ,
#        0.0204466 , 0.0204466 , 0.02042554, 0.01870913, 0.01756291,
#        0.01741106, 0.01629007, 0.01596154, 0.01551138, 0.01435005,
#        0.01321122, 0.01236583, 0.01206255, 0.01104295, 0.01071499,
#        0.01049079, 0.01040887, 0.01039089, 0.01037741, 0.01035414,
#        0.01034034, 0.01029605, 0.01028233, 0.01028139, 0.01028139,
#        0.01028138, 0.01027965, 0.01027051, 0.01026331, 0.01026202,
#        0.01025761, 0.01025565, 0.01025068, 0.01024924, 0.01024279,
#        0.01024259, 0.01024259, 0.0102419 , 0.01024018, 0.01023676,
#        0.01023495, 0.01023   , 0.01022442, 0.0102233 , 0.0102233 ,
#        0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 ,
#        0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 ,
#        0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 ,
#        0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 , 0.0102233 ,
# ...

# %%
# Using t-SNE for further dimentionality reduction.

# %%
t_sne = TSNE(learning_rate=300)
tsnereduced = t_sne.fit_transform(cryptoreduced)

# %%
tsnereduced.shape
# Out:
# (532, 2)

# %%
# Using a scatterplot to display results

# %%
plt.scatter(tsnereduced[:,0], tsnereduced[:,1])
plt.show()

# %%
# For-loop to determine the inertia for each k, 1 through 10.

# %%
inertia = []
k = list(range(1, 11))

# %%
for i in k:
    k_means = KMeans(n_clusters=i, random_state=0)
    k_means.fit(cryptoreduced_df)
    inertia.append(k_means.inertia_)
# Out:
# C:\Users\Sam\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
# Use hvPlot for Elbow Curve.

# %%
elbowcurve = {"k": k, "inertia": inertia}
elbowcurve_df = pd.DataFrame(elbowcurve)

elbowcurve_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-0962cf454626> in <module>
#       1 elbowcurve = {"k": k, "inertia": inertia}
# ----> 2 elbowcurve_df = pd.DataFrame(elbowcurve)
#       3
#       4 elbowcurve_df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# ...

# %%
# Elbow Curve plot.

# %%
plt.plot(elbowcurve_df['k'], elbowcurve_df['inertia'])
plt.xticks(range(1,11))
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-cb8cbec7078d> in <module>
# ----> 1 plt.plot(elbowcurve_df['k'], elbowcurve_df['inertia'])
#       2 plt.xticks(range(1,11))
#       3 plt.xlabel('Number of clusters')
#       4 plt.ylabel('Inertia')
#       5 plt.show()
#
# NameError: name 'elbowcurve_df' is not defined
